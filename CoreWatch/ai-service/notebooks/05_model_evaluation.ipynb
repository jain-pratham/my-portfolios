# %% [markdown]
# # 05. Model Evaluation & Benchmarks
#
# This notebook contains standard evaluation metrics (mAP, F1-score, confusion matrix) for trained YOLO models.
#
# ### TODO:
# - Load validation datasets
# - Run model predictions and calculate mAP metrics
# - Benchmark inference latency

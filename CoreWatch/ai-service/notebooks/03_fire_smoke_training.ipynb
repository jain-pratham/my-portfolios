# %% [markdown]
# # 03. Custom Fire & Smoke Model Training
#
# This notebook will be used for training YOLO models on custom fire and smoke datasets.
#
# ### TODO:
# - Load custom fire & smoke dataset
# - Fine-tune YOLOv8 models
# - Export custom weights

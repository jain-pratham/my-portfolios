# %% [markdown]
# # 02. Dataset Analysis
#
# This notebook contains dataset structure, distribution analysis, and preprocessing workflows.
#
# ### TODO:
# - Load custom dataset labels
# - Check distribution of classes (person, fire, smoke, suspicious objects)
# - Augment low-represented classes

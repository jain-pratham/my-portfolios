# %% [markdown]
# # 04. Custom Object Training
#
# This notebook will be used for training YOLO models on custom suspicious-object categories.
#
# ### TODO:
# - Load custom object detection datasets
# - Fine-tune and evaluate pretrained models
